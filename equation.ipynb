# %%
# import sympy as sp
from sympy import *
# import plotly as plt
# import matplotlib.pyplot as plt
x = Symbol('x')
eq = sin(x)**2 - cos(x)**2

# %%
# вершина, при которых функция равна нулю
dec=solveset(eq)
dec
# Out:
# Union(ImageSet(Lambda(_n, _n*pi + pi/4), Integers), ImageSet(Lambda(_n, _n*pi + 3*pi/4), Integers))

# %%
# график
plot(eq)

# %%
# производная
derivative = diff(eq)
derivative
# Out:
# 4*sin(x)*cos(x)

# %%
# возрастание
increase=solve(derivative>0)
increase
# Out:
# (0 < x) & (x < pi/2)

# %%
# убывание
decreases=solve(derivative<0)
decreases
# Out:
# (x < pi) & (pi/2 < x)

# %%
# функция больше нуля
up_eq=solve(eq>0)
up_eq
# Out:
# (pi/4 < x) & (x < 3*pi/4)

# %%
# функция меньше нуля
down_eq=solve(eq<0)
down_eq
# Out:
# ((0 <= x) & (x < pi/4)) | ((x < pi) & (3*pi/4 < x))
